# %% [markdown]
# # Executor
# ### Use to take measurements

# %%
import nidaqmx
from nidaqmx import Task
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DAQ
from data_structures import experiment

# Live plots
import matplotlib
# %matplotlib notebook
import IPython
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 70em; width:120em}</style>"))
# Out:
# <style>div.output_scroll { height: 70em; width:120em}</style>

# %% [markdown]
# # Electrochemical Impedance Spectroscopy

# %%
'''=========================USER INPUTS========================================'''
E_DC = .40 # DC potential in V
E_AC = 0.010 # AC perturbation in V
low_freq = 1 # Lower limit of frequencies to be measured in Hz

Rm = 1000 # Rm resistance in Ohms
Cm = 10.0e-6 # Cm capacitance in Farads

# %%
df_EIS, params_EIS = DAQ.take_EIS(E_DC, E_AC, low_freq, Rm)
latest_EIS = experiment(df_EIS, params_EIS)
latest_EIS.to_excel()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# # Cyclic Voltammetry

# %%
'''=========================USER INPUTS========================================'''
samp_rate = 3600 # sampling rate (samples/s) Use an integral multiple of 120/s and at least 3600 per volt
scan_rate = .100 # scan rate (V/s)
# buffer_size = 3600 # passed as a default argument, but changeable.

'''Set up potential profile'''
h_time = 0.3  # hold time before sweep in seconds
# potential bounds for each section
f_start_pot = 0  # Initial potential
f_end_pot = 0.4   # Vertex potential

pot_profile, samp_num_tot = DAQ.set_potential_profile(f_start_pot, f_end_pot, samp_rate, scan_rate, h_time)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df_CV, params_CV = DAQ.take_CV(pot_profile, samp_num_tot, Rm)
latest_CV = experiment(df_CV, params_CV)
latest_CV.to_excel()
# Out:
# <img src="data:image/png;base64,..." width="1400">
# Must press Enter to end execution of code block
# <img src="data:image/png;base64,..." width="1400">
# Must press Enter to end execution of code block
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18280/2888572870.py in <module>
#       1 df_CV, params_CV = DAQ.take_CV(pot_profile, samp_num_tot, Rm)
#       2 exp = experiment(df_CV, params_CV)
# ----> 3 exp1 = experiment(*DAQ.take_CV(pot_profile, samp_num_tot, Rm))
#
# ~\Documents\GitHub\CHEM274\DAQ.py in take_CV(pot_profile, samp_num_tot, Rm, buffer_size, samp_rate)
#     568         data = pd.DataFrame(columns=['E_program', 'Ecell', 'iw', 't'])
#     569         data['E_program'] = pot_profile
# --> 570         data['Ecell'] = total_data_WE
#     571         data['iw'] = np.array(total_data_RM) / Rm
#     572         data['t'] = np.abs(np.arange(0, len(total_data_WE), 1) / samp_rate)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (14400) does not match length of index (32400)

# %%
exp.to_excel()
# Out:
# C:\Users\jgage\Documents\GitHub\CHEM274\data_structures.py:26: ResourceWarning: unclosed file <_io.BufferedWriter name='C:/Users/jgage/Documents/GitHub/CHEM274/data/CV-dummy-cell.xlsx'>
#   self.filepath = self.filepath.name
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
# Out:
# C:\Users\jgage\Documents\GitHub\CHEM274\data_structures.py:26: ResourceWarning: unclosed file <_io.BufferedWriter name='C:/Users/jgage/Documents/GitHub/CHEM274/data/EIS-dummy-cell.xlsx'>
#   self.filepath = self.filepath.name
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
